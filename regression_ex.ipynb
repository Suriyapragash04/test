# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as ss
from sklearn import linear_model

# %%
X = [[1,1]]
type(x)
# Out:
# pandas.core.series.Series

# %%
df = pd.read_csv("real.csv")
df
# Out:
#          price     size
# 0   234314.144   643.09
# 1   228581.528   656.22
# 2   281626.336   487.29
# 3   401255.608  1504.75
# 4   458674.256  1275.46
# ..         ...      ...
# 95  252460.400   549.80
# 96  310522.592  1037.44
# 97  383635.568  1504.75
# 98  225145.248   648.29
# 99  274922.856   705.29
#
# [100 rows x 2 columns]

# %%
x = df['price']
y = df['size']

# %%
regr = linear_model.LinearRegression()
regr.fit(df[["price"]], y)
# Out:
# LinearRegression()

# %%
regr.predict([[340400]])
# Out:
# array([1013.56725371])

# %%
plt.plot(df['price'], df['size'], 'o')

# %%
slope, intercept, r, p, se = ss.linregress(df['price'], df['size'])
se
# Out:
# 0.00019734599322429532

# %%
def myfunc(x):
    return slope*x+intercept

# %%
x = 401255.608
y=myfunc(x)
y
# Out:
# 1216.640160538193

# %%
model = list(map(myfunc, df['price']))
model
# Out:
# [659.5626868449933,
#  640.4331598693989,
#  817.4417167919669,
#  1216.640160538193,
#  1408.2440593198585,
#  695.3887744855487,
#  762.3909319935925,
#  464.02445539973087,
#  982.53798351448,
#  607.2273088980481,
#  810.5300657319743,
#  1528.7242242670159,
#  596.6874981954783,
#  1275.0283353789225,
#  1359.917334874466,
#  1346.6015447697048,
#  706.358439402475,
#  659.1089132804899,
#  629.9899876127347,
#  876.8084226367484,
#  772.388526266663,
#  450.9394229541981,
#  1254.3941050874537,
#  489.86258591610294,
#  438.43256605049487,
#  1087.3799389535616,
#  784.6292803999833,
#  1235.31612751491,
#  871.2806234438418,
#  1108.965790980167,
#  884.2123157696834,
#  629.9911088322729,
#  570.893255415313,
#  516.6497486843926,
#  829.4442384691376,
#  885.4309479291148,
#  776.0619885177213,
#  656.8232538606043,
#  855.2791388054119,
#  697.7143706775544,
#  912.2761204606513,
#  603.3484766015887,
#  836.541371275581,
#  1261.4456950240863,
#  855.5436932250041,
# ...

# %%
plt.plot(df['price'], model)
plt.plot(x,y,'o')

# %%
plt.plot(df['price'],df['size'], 'bo')
plt.plot(df['price'], model, 'red')

# %%
a=list(map(myfunc, df['price']))
a
# Out:
# [659.5626868449933,
#  640.4331598693989,
#  817.4417167919669,
#  1216.640160538193,
#  1408.2440593198585,
#  695.3887744855487,
#  762.3909319935925,
#  464.02445539973087,
#  982.53798351448,
#  607.2273088980481,
#  810.5300657319743,
#  1528.7242242670159,
#  596.6874981954783,
#  1275.0283353789225,
#  1359.917334874466,
#  1346.6015447697048,
#  706.358439402475,
#  659.1089132804899,
#  629.9899876127347,
#  876.8084226367484,
#  772.388526266663,
#  450.9394229541981,
#  1254.3941050874537,
#  489.86258591610294,
#  438.43256605049487,
#  1087.3799389535616,
#  784.6292803999833,
#  1235.31612751491,
#  871.2806234438418,
#  1108.965790980167,
#  884.2123157696834,
#  629.9911088322729,
#  570.893255415313,
#  516.6497486843926,
#  829.4442384691376,
#  885.4309479291148,
#  776.0619885177213,
#  656.8232538606043,
#  855.2791388054119,
#  697.7143706775544,
#  912.2761204606513,
#  603.3484766015887,
#  836.541371275581,
#  1261.4456950240863,
#  855.5436932250041,
# ...

# %% [markdown]
# # Multiple linear regression

# %%
import pandas as ph
import sklearn.linear_model as slm

# %%
df = ph.read_csv('cars.csv')

# %%
X = [[df['Weight'],df['Volume']]]
z = ph.DataFrame({'Weight' : df['Weight'],
                'Volume' : df['Volume']})
y = df['CO2']
x = df[['Weight', 'Volume']]
type(X)
# Out:
# list

# %%
reg = slm.LinearRegression()
reg.fit(z,y)
# Out:
# LinearRegression()

# %%
predict = reg.predict([[2300,1200]])
predict
# Out:
# array([106.42820705])

# %% [markdown]
# # Polynomial regression

# %%
import numpy
import matplotlib.pyplot as plt

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

# %%
mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

# %%
myline = numpy.linspace(1, 22, 100)

# %%
plt.scatter(x, y)

# %%
plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()
